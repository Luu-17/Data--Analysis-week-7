# %%
import pandas as pd
osd_df = pd.read_csv ('owid-covid-data.csv')

# %%
# Columns check 
osd_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
# Our Head 
osd_df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# missing values

missing_values = osd_df.isnull().sum()
missing_values = missing_values[missing_values > 0]
print(missing_values)
# Out:
# continent                                   14352
# total_cases                                 35741
# new_cases                                    8448
# new_cases_smoothed                           9712
# total_deaths                                56298
#                                             ...
# human_development_index                     75300
# excess_mortality_cumulative_absolute       292217
# excess_mortality_cumulative                292217
# excess_mortality                           292217
# excess_mortality_cumulative_per_million    292217
# Length: 63, dtype: int64

# %%
osd_df_copy = osd_df.copy()

# %%
osd_df_copy
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 302507      ZWE    Africa     Zimbabwe  2023-04-08     264578.0        2.0
# 302508      ZWE    Africa     Zimbabwe  2023-04-09     264582.0        4.0
# 302509      ZWE    Africa     Zimbabwe  2023-04-10     264584.0        2.0
# 302510      ZWE    Africa     Zimbabwe  2023-04-11     264584.0        0.0
# 302511      ZWE    Africa     Zimbabwe  2023-04-12     264584.0        0.0
#
# ...

# %%
# Countries in the CSV

# available_countries = osd_df_copy['location'].unique()
# print(available_countries)




display(pd.DataFrame(available_countries, columns=['Available Countries']))
display(pd.DataFrame(available_countries, columns=['random Countries']).sample(3))

# Sampling and picking 3 random data of interest (Western Sahara, Barbados, Belarus)
# Out:
#     Available Countries
# 0           Afghanistan
# 1                Africa
# 2               Albania
# 3               Algeria
# 4        American Samoa
# ..                  ...
# 250      Western Sahara
# 251               World
# 252               Yemen
# 253              Zambia
# 254            Zimbabwe
#
# [255 rows x 1 columns]
#     random Countries
# 250   Western Sahara
# 19          Barbados
# 20           Belarus

# %%
countries_of_interest = ['Belarus','Barbados','Western Sahara']

# %%
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 302507      ZWE    Africa  Zimbabwe  2023-04-08     264578.0        2.0
# 302508      ZWE    Africa  Zimbabwe  2023-04-09     264582.0        4.0
# 302509      ZWE    Africa  Zimbabwe  2023-04-10     264584.0        2.0
# 302510      ZWE    Africa  Zimbabwe  2023-04-11     264584.0        0.0
# 302511      ZWE    Africa  Zimbabwe  2023-04-12     264584.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 302507               4.143        5684.0         1.0                0.571
# 302508               4.714        5684.0         0.0                0.571
# 302509               4.143        5684.0         0.0                0.571
# 302510               3.143        5684.0         0.0                0.571
# 302511               2.571        5684.0         0.0                0.429
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
print("Filtered Data:")
display(filtered_df)
# Out:
# Filtered Data:
#        iso_code      continent        location        date  total_cases  \
# 22726       BRB  North America        Barbados  2020-01-03          NaN
# 22727       BRB  North America        Barbados  2020-01-04          NaN
# 22728       BRB  North America        Barbados  2020-01-05          NaN
# 22729       BRB  North America        Barbados  2020-01-06          NaN
# 22730       BRB  North America        Barbados  2020-01-07          NaN
# ...         ...            ...             ...         ...          ...
# 25114       BLR         Europe         Belarus  2023-04-09     994037.0
# 25115       BLR         Europe         Belarus  2023-04-10     994037.0
# 25116       BLR         Europe         Belarus  2023-04-11     994037.0
# 25117       BLR         Europe         Belarus  2023-04-12     994037.0
# 297727      ESH         Africa  Western Sahara  2022-04-20          NaN
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
filtered_df_cleaned = filtered_df.dropna(subset=['total_cases'])
display(filtered_df_cleaned)
# Out:
#       iso_code      continent  location        date  total_cases  new_cases  \
# 22801      BRB  North America  Barbados  2020-03-18          2.0        2.0
# 22802      BRB  North America  Barbados  2020-03-19          2.0        0.0
# 22803      BRB  North America  Barbados  2020-03-20          2.0        0.0
# 22804      BRB  North America  Barbados  2020-03-21          5.0        3.0
# 22805      BRB  North America  Barbados  2020-03-22          5.0        0.0
# ...        ...            ...       ...         ...          ...        ...
# 25113      BLR         Europe   Belarus  2023-04-08     994037.0        0.0
# 25114      BLR         Europe   Belarus  2023-04-09     994037.0        0.0
# 25115      BLR         Europe   Belarus  2023-04-10     994037.0        0.0
# 25116      BLR         Europe   Belarus  2023-04-11     994037.0        0.0
# 25117      BLR         Europe   Belarus  2023-04-12     994037.0        0.0
#
# ...
